# %%
import time
import pandas as pd
import numpy as np
import math

# internal tools
from dsgtools.reporting import make_format
from dsgtools.reporting import TableWriter
from dsgtools.reporting import freq
from dsgtools.reporting import bivariate

# %%
path = "Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/"

# %%
shell = pd.read_adls(path + "/_temp/" + "busishell_v31" + "_all.parquet", reader = pd.read_parquet)
print(shell.shape)
biid = pd.read_adls(path + "/_temp/" + "biid" + "_all.parquet", reader = pd.read_parquet)
print(biid.shape)
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 shell = pd.read_adls(path + "/_temp/" + "busishell_v31" + "_all.parquet", reader = pd.read_parquet)
#       2 print(shell.shape)
#       3 biid = pd.read_adls(path + "/_temp/" + "biid" + "_all.parquet", reader = pd.read_parquet)
#
# File /anaconda/envs/data-science/lib/python3.10/site-packages/dsgtools/azure/adls.py:197, in read_adls(uri, reader, storage_account, file_system, stream_file, connection_object, max_concurrency, **kwargs)
#     185 file_fisher = _get_file_fisher_object(
#     186     client=connection_object,
#     187     storage_account=storage_account,
#     188     file_system=file_system,
#     189 )
#     191 # If this is a parquet file, and it's a directory, we should iterate through all
#     192 # files and concatenate.
# ...
