# %%
import time
import pandas as pd
import numpy as np
import math

# internal tools
from dsgtools.reporting import make_format
from dsgtools.reporting import TableWriter
from dsgtools.reporting import freq
from dsgtools.reporting import bivariate

# %% [markdown]
# ## Additional cleaning

# %%
## dedupped data
data = pd.read_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_filtered_remove_dt_dedup_for_ECL.csv",
                    reader = pd.read_csv, dtype = str)
print(data.shape)
# Out:
# (17311232, 10)

# %%
data.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate'],
#       dtype='object')

# %%
data["weird_name"] = np.where(data['CompanyName'].str.contains("CDATA") | data['CompanyName'].str.contains(",!.; -@!%^&*), 1, 0)
freq(data["weird_name"])
# Out:
#                  Count       Pct  Cuml Count  Cuml Pct
# weird_name
# 0           17301945.0  0.999464  17301945.0  0.999464
# 1               9287.0  0.000536  17311232.0  1.000000

# %%
data.iloc[15000:15005]
# Out:
#             AccountNumber              CompanyName AlternateCompanyName  \
# 15000  AAA000000103049078   1 OF ONE LOGISTICS LLC                  NaN
# 15001  AAA000000097149727   1 OF ONE LOGISTICS LLC                  NaN
# 15002  AAA000000090463360   1 OF ONE LOGISTICS LLC                  NaN
# 15003  AAA000000082985045  1 OF ONE LOGISTICS, LLC                  NaN
# 15004  AAA000000105713415       1 OF THE OFF BEATS                  NaN
#
#                            Addr    City State        Zip BusinessPhone  \
# 15000   1008 S NEBRASKA STREET   MARION    IN      46953           NaN
# 15001   1008 S NEBRASKA STREET   MARION    IN      46953    7656614089
# 15002   1008 S NEBRASKA STREET   MARION    IN  469532125    7656614089
# 15003  1408 S WESTERN AVE 1007   MARION    IN  469531540    7656614089
# 15004     1534 SELWYN AVE # 2G      NaN   NaN      10457           NaN
#
#       TaxIdNumber HistoryDate  weird_name
# 15000   872055608    20220323           0
# 15001         NaN    20220509           0
# 15002         NaN    20220418           0
# 15003         NaN    20220323           0
# 15004         NaN    20210801           0

# %%
df['E'] = re.sub(r'\W+', '', df['B'].str)

# %% [markdown]
# ## Input

# %%
path = "Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_e_total.csv.gz"
data = pd.read_adls(path, reader = pd.read_csv, compression = "gzip", dtype = str)
print(data.shape)
# Out:
# (101176653, 27)

# %%
data = data.drop(axis = 0, index = [0])
print(data.shape)
# Out:
# (101176652, 27)

# %%
data.columns
# Out:
# Index(['account', 'first_name', 'alternateCompanyName', 'new_address',
#        'new_city', 'new_state', 'new_zip', 'new_phone1', 'new_ssn',
#        'businessIPAddress', 'representativeFirstName',
#        'representativeMiddleName', 'representativeLastName',
#        'representativeNameSuffix', 'representativeAddr', 'representativeCity',
#        'representativeState', 'representativeZip', 'representativeSSN',
#        'representativeDOB', 'representativeAge', 'representativeDLNumber',
#        'representativeDLState', 'representativeHomePhone',
#        'representativeEmailAddress', 'representativeFormerLastName',
#        'final_date'],
#       dtype='object')

# %%
column_name = ['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'BusinessIPAddress', 
'RepresentativeFirstName', 'RepresentativeMiddleName', 'RepresentativeLastName', 'RepresentativeNameSuffix', 'RepresentativeAddr', 'RepresentativeCity', 
'RepresentativeState', 'RepresentativeZip', 'RepresentativeSSN', 'RepresentativeDOB', 'RepresentativeAge', 'RepresentativeDLNumber', 'RepresentativeDLState', 
'RepresentativeHomePhone', 'RepresentativeEmailAddress', 'RepresentativeFormerLastName', 'HistoryDate']
data.columns = column_name

# %%
## keep columns needed for Engineer processing
data = data[['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate']]
data = data.fillna("")

# %%
data.loc[~((data.BusinessPhone.str.isnumeric())| (data.BusinessPhone ==""))]
# Out:
#         AccountNumber    CompanyName AlternateCompanyName        Addr City  \
# 1  AAA000000000000005  MOUNTAIN VIEW                       725606465   840
#
#   State Zip BusinessPhone TaxIdNumber HistoryDate
# 1    87       AZZAAZFAABF

# %%
data.loc[~((data.TaxIdNumber.str.isnumeric())| (data.TaxIdNumber ==""))].head(5)
# Out:
#                AccountNumber  \
# 89148995  AAA000000101121833
# 89248641  AAA000000101224590
# 89248642  AAA000000101224591
# 89248643  AAA000000101224593
# 89248644  AAA000000101224594
#
#                                                 CompanyName  \
# 89148995                            CONNICK AND CONNICK LLC
# 89248641  WVCZVZCRDDHMMVWMQY+BAK8EDHH4VR8J+CP0GW4ECCPOIG...
# 89248642  W4GXM8E/ULJLMW/4WGW9PDOJEEERB9LSEBO+X5DSEETXHI...
# 89248643  YA8/TDOEE+VMZT2VY302SR4/SB/6QO5KMLZKGC+GD4G0QG...
# 89248644  6GKWMXQ335W0FW+FQLQJTIOLOXXUOL+PTL1UXU6FHQ1ULH...
#
#          AlternateCompanyName  \
# 89148995
# 89248641
# 89248642
# 89248643
# 89248644
#
#                                                        Addr       City State  \
# 89148995                     3421 NO CAUSEWAY BLVD STE 408    METAIRIE    LA
# 89248641  NCX0WMBNTCMSXL6YKMUYGQXAQVXG+2JBW/EAXDBW6/ICOV...  PRIMARY>>    CU
# 89248642  AW/HIUKMT33TXYFYDMBZSF9Q34FQS6SUMPDULJND5QXYSG...  PRIMARY>>    CU
# 89248643  G8LF2+LLNKQ3T7G2/ETEZ+SR6V8BILPQBRCVYHPT3VCGN7...  PRIMARY>>    CU
# 89248644  XD0RVT2XQ9KIH49PLE9AUAUSJN/RN+ACJGYID87TGFWXKO...  PRIMARY>>    CU
#
#             Zip BusinessPhone  TaxIdNumber HistoryDate
# 89148995  70002                W+HBR67PVA8    20210802
# 89248641                       SQN7HSEL2OS    20210813
# 89248642                       EXWCDUU5FH4    20210813
# 89248643                       XEJESBOLCVX    20210813
# 89248644                       AEZSA0KO8SF    20210813

# %%
data.loc[~(((~data.State.str.isnumeric())| (data.State =="")))].head(5)
# Out:
#                AccountNumber                       CompanyName  \
# 1         AAA000000000000005                     MOUNTAIN VIEW
# 88945472  AAA000000100912819  INTELLIGENT LIGHTING DESIGN, LLC
# 88986425  AAA000000100954820     BF HOMES, LLC : BF HOMES, LLC
# 89074171  AAA000000101044961   RHETT FONTENOT CONSTRUCTION LLC
# 89100384  AAA000000101071800     ![CDATA[JARM ONE, A NV LLC]]>
#
#          AlternateCompanyName             Addr          City State        Zip  \
# 1                                   725606465            840    87
# 88945472                        1300 W 9TH ST      CLEVELAND    44
# 88986425                             BF HOMES            LLC    99  DUNGAN RD
# 89074171                       640 JONQUIL DR   LAKE CHARLES    70
# 89100384                                 4815           4831    49   CRAIG RD
#
#          BusinessPhone TaxIdNumber HistoryDate
# 1          AZZAAZFAABF
# 88945472                 851674199    20210706
# 88986425                 833629737    20210712
# 89074171                              20210722
# 89100384                 451162986    20210726

# %%
data.loc[~(((~data.City.str.isnumeric())| (data.City =="")))].head(5)
# Out:
#                AccountNumber                  CompanyName  \
# 1         AAA000000000000005                MOUNTAIN VIEW
# 216387    AAA000000000443032                SUZANNE WHITE
# 905009    AAA000000003264640                SUZANNE WHITE
# 14817496  AAA000000018929645  USSHER INVENTIONS (PTY) LTD
# 30143365  AAA000000035769903                SUZANNE WHITE
#
#          AlternateCompanyName         Addr  City State    Zip BusinessPhone  \
# 1                               725606465    840    87          AZZAAZFAABF
# 216387                                  0      0    ME           2079233235
# 905009                                  0      0    ME           2079233235
# 14817496                       3 SIGMA RD   1401    ZA  01401     118251100
# 30143365                                0      0    ME           2079233235
#
#          TaxIdNumber HistoryDate
# 1
# 216387                  20210528
# 905009                  20210603
# 14817496                20210716
# 30143365                20211008

# %%
data.loc[~(((~data.Addr.str.isnumeric())| (data.Addr =="")))].head(5)
# Out:
#                AccountNumber         CompanyName AlternateCompanyName Addr  \
# 4445085   AAA000000007552034          EVA POLINI                       737
# 7660961   AAA000000011292284          EVA POLINI                       737
# 10691061  AAA000000014685537  K B SALES CO. INC.                       520
# 12558205  AAA000000016585444  K B SALES CO. INC.                       520
# 15657694  AAA000000019775614  K B SALES CO. INC.                       520
#
#                      City State    Zip BusinessPhone TaxIdNumber HistoryDate
# 4445085     BEVERLY HILLS    CA  90210    3102772226                20210630
# 7660961     BEVERLY HILLS    CA  90210    3102772226                20210703
# 10691061  NORTH SALT LAKE    UT  84054    8012962868                20210705
# 12558205  NORTH SALT LAKE    UT  84054    8012962868                20210709
# 15657694  NORTH SALT LAKE    UT  84054    8012962868                20210719

# %%
data.loc[~(((~data.CompanyName.str.isnumeric())| (data.CompanyName =="")))].head(5)
# Out:
#            AccountNumber CompanyName AlternateCompanyName  \
# 12    AAA000000000030674        1977
# 7031  AAA000000000037736        1952
# 7033  AAA000000000037738        1958
# 7034  AAA000000000037739        1958
# 7035  AAA000000000037740        1961
#
#                            Addr             City State        Zip  \
# 12       203 MEADOWLINK STREET           HOUSTON    TX  770374305
# 7031  10304 INDIAN MOUND DRIVE   NEW PORT RICHEY    FL  346543522
# 7033        978 TRILLIUM TRAIL           OSHKOSH    WI  549047670
# 7034        978 TRILLIUM TRAIL           OSHKOSH    WI  549047670
# 7035       10 WELLINGTON COURT        SAYREVILLE    NJ  088721370
#
#      BusinessPhone TaxIdNumber HistoryDate
# 12      8322303319                20191125
# 7031    7272437770                20191125
# 7033    9204108070                20191125
# 7034    9204108070                20191125
# 7035    6093841717                20191125

# %%
data.loc[~((data.CompanyName.str.contains("[a-zA-Z0-9]")) | (data.CompanyName !="") | (data.CompanyName !=" "))].head(5)
# Out:
# Empty DataFrame
# Columns: [AccountNumber, CompanyName, AlternateCompanyName, Addr, City, State, Zip, BusinessPhone, TaxIdNumber, HistoryDate]
# Index: []

# %%
data = data[data.HistoryDate != ""]
print(data.shape)
data = data[data.CompanyName.str.strip() != ""]
print(data.shape)
## remove Phone with not numbers
data = data.loc[(data.BusinessPhone.str.isnumeric())| (data.BusinessPhone =="")]
print(data.shape)
## remove TaxIdNumber with not numbers
data = data.loc[(data.TaxIdNumber.str.isnumeric())| (data.TaxIdNumber =="")]
print(data.shape)
## remove addr, city, state without character
data = data.loc[(~data.State.str.isnumeric())| (data.State =="")]
print(data.shape)
data = data.loc[(~data.City.str.isnumeric())| (data.City =="")]
print(data.shape)
data = data.loc[(~data.Addr.str.isnumeric())| (data.Addr =="")]
print(data.shape)
# Out:
# (101176651, 10)
# (101174569, 10)
# (101174569, 10)
# (101154745, 10)
# (101154692, 10)
# (101152182, 10)
# (101152150, 10)

# %%
data.head()
# Out:
#         AccountNumber                                      CompanyName  \
# 2  AAA000000000030664            1 BODY STRENGTH AND CONDI TIONING LLC
# 3  AAA000000000030665                                    1 EIGHTY LABS
# 4  AAA000000000030666  1 SPARTAN TECHNOLOGY SOLUTISPARTAN TECHNOLOGY S
# 5  AAA000000000030667  1 SPARTAN TECHNOLOGY SOLUTISPARTAN TECHNOLOGY S
# 6  AAA000000000030668                               1013 ATHLETICS LLC
#
#   AlternateCompanyName                        Addr         City State  \
# 2                       2160 LONG BEACH BOULEVARD    LONG BEACH    CA
# 3                         701 5TH AVENUE STE 4200       SEATTLE    WA
# 4                           125 VENTURE BOULEVARD   SPARTANBURG    SC
# 5                           125 VENTURE BOULEVARD   SPARTANBURG    SC
# 6                               726 FOSTER AVENUE   BENSENVILLE    IL
#
#          Zip BusinessPhone TaxIdNumber HistoryDate
# 2  908064807    5623307372                20191125
# 3  981047047    2062627302                20191125
# 4  293063817    8645871386                20191125
# 5  293063817    8645871386                20191125
# 6      60106                              20191125

# %%
print(data[data['AccountNumber'].str.strip() == ""].shape)
print(data[data['CompanyName'].str.strip() == ""].shape)
print(data[data['AlternateCompanyName'].str.strip() == ""].shape)
print(data[data['Addr'].str.strip() == ""].shape)
print(data[data['City'].str.strip() == ""].shape)
print(data[data['State'].str.strip() == ""].shape)
print(data[data['Zip'].str.strip() == ""].shape)
print(data[data['BusinessPhone'].str.strip() == ""].shape)
print(data[data['TaxIdNumber'].str.strip() == ""].shape)
print(data[data['HistoryDate'].str.strip() == ""].shape)
# Out:
# (0, 10)
# (0, 10)
# (101152150, 10)
# (3, 10)
# (4204895, 10)
# (4198817, 10)
# (5361736, 10)
# (31250392, 10)
# (95845741, 10)
# (0, 10)

# %%
data["sufficient_input"] = np.where(data["CompanyName"].isnull() |
                              (data["Addr"].isnull() | data["City"].isnull() | data["State"].isnull()) &
                              (data["Addr"].isnull() | data["Zip"].isnull()), 1, 0)
freq(data["sufficient_input"])
# Out:
#                         Count  Pct   Cuml Count  Cuml Pct
# sufficient_input
# 0                 101152150.0  1.0  101152150.0       1.0

# %%
data.dtypes
# Out:
# AccountNumber           object
# CompanyName             object
# AlternateCompanyName    object
# Addr                    object
# City                    object
# State                   object
# Zip                     object
# BusinessPhone           object
# TaxIdNumber             object
# HistoryDate             object
# sufficient_input         int64
# dtype: object

# %%
data.to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_futher_filtered.parquet", 
             format = '.parquet', overwrite = True)

# %% [markdown]
# ## Dedup by BII for Engineering

# %%
data.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',
#        'sufficient_input'],
#       dtype='object')

# %%
data["count"] = 1
dedup_bii =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ])['count'].sum().reset_index(name='count')
freq(dedup_bii["count"])
# Out:
#             Count           Pct  Cuml Count  Cuml Pct
# count
# 1       9218466.0  4.661482e-01   9218466.0  0.466148
# 2       3391872.0  1.715161e-01  12610338.0  0.637664
# 3        898848.0  4.545185e-02  13509186.0  0.683116
# 4        606188.0  3.065298e-02  14115374.0  0.713769
# 5        319605.0  1.616140e-02  14434979.0  0.729930
# ...           ...           ...         ...       ...
# 45946         1.0  5.056679e-08  19775823.0  1.000000
# 54648         1.0  5.056679e-08  19775824.0  1.000000
# 66412         1.0  5.056679e-08  19775825.0  1.000000
# 91744         1.0  5.056679e-08  19775826.0  1.000000
# 554803        1.0  5.056679e-08  19775827.0  1.000000
#
# [356 rows x 4 columns]

# %%
fmt = make_format(cuts = [-np.inf, 0, 1, 2, 3, 4, 5, 10, 100, 1000, np.inf])
freq(dedup_bii["count"], format = [fmt])
# Out:
#               Count       Pct  Cuml Count  Cuml Pct
# count
# <= 0            0.0  0.000000         0.0  0.000000
# 1         9218466.0  0.466148   9218466.0  0.466148
# 2         3391872.0  0.171516  12610338.0  0.637664
# 3          898848.0  0.045452  13509186.0  0.683116
# 4          606188.0  0.030653  14115374.0  0.713769
# 5          319605.0  0.016161  14434979.0  0.729930
# 6-10      1319742.0  0.066735  15754721.0  0.796666
# 11-100    4020233.0  0.203290  19774954.0  0.999956
# 101-1000      837.0  0.000042  19775791.0  0.999998
# 1001+          36.0  0.000002  19775827.0  1.000000
# Missing         0.0  0.000000  19775827.0  1.000000

# %%
dedup_bii[dedup_bii["count"] == 554803]
# Out:
#                                 CompanyName AlternateCompanyName  \
# 7325786  GORMAN MANUFACTURING COMPANY, INC.
#
#                    Addr           City State    Zip BusinessPhone TaxIdNumber  \
# 7325786  492 KOLLER ST   SAN FRANCISCO    CA  94110    6505550000
#
#           count
# 7325786  554803

# %%
data = data.sort_values(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', "HistoryDate"])

# %%
dedup_bii = data.drop_duplicates(subset=['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ], 
                                 keep = "last", ignore_index = True)
print(dedup_bii.shape)
# Out:
# (19775827, 12)

# %%
dedup_bii.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',
#        'sufficient_input', 'count'],
#       dtype='object')

# %%
dedup_bii[['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
       'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',]].to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_futher_filtered_dedup_for_ECL.csv", 
             format = '.csv', overwrite = True, index = False)

# %%
dedup_bii[['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
       'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',]].sample(n=1_000_000, random_state=1234, ignore_index = True).to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_futher_filtered_dedup_for_ECL_1mil_sample.csv", 
             format = '.csv', overwrite = True)

# %% [markdown]
# #### Further remove records - By time

# %%
data = pd.read_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_futher_filtered.parquet", reader = pd.read_parquet)
print(data.shape)
# Out:
# (101152150, 11)

# %%
freq(data.HistoryDate.str.slice(0,6))
# Out:
#                   Count       Pct   Cuml Count  Cuml Pct
# HistoryDate
# 201911          18374.0  0.000182      18374.0  0.000182
# 202105         322253.0  0.003186     340627.0  0.003367
# 202106        7956225.0  0.078656    8296852.0  0.082023
# 202107       10580351.0  0.104598   18877203.0  0.186622
# 202108        4961686.0  0.049052   23838889.0  0.235674
# 202109        7551680.0  0.074657   31390569.0  0.310330
# 202110        8729360.0  0.086299   40119929.0  0.396630
# 202111        7075626.0  0.069950   47195555.0  0.466580
# 202112        7874424.0  0.077847   55069979.0  0.544427
# 202201       10880052.0  0.107561   65950031.0  0.651988
# 202202        3967399.0  0.039222   69917430.0  0.691211
# 202203       15275783.0  0.151018   85193213.0  0.842228
# 202204        5498433.0  0.054358   90691646.0  0.896586
# 202205        7674972.0  0.075876   98366618.0  0.972462
# 202206        2785532.0  0.027538  101152150.0  1.000000

# %%
data = data[~data.HistoryDate.str. slice(0, 6).isin(["201911", "202105", "202106"])]
print(data.shape)
# Out:
# (92855298, 11)

# %%
temp = pd.read_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data/temp_stacked_datetime_for_merge.parquet")
print(temp.shape)
# Out:
# (106154115, 2)

# %%
data = data.merge(temp, on = "AccountNumber")
print(data.shape)
# Out:
# (92855298, 12)

# %%
data.head()
# Out:
#         AccountNumber                       CompanyName AlternateCompanyName  \
# 0  AAA000000010112675  FAMILY SOLUTIONS COUNSELING, LLC
# 1  AAA000000010112676             GLORIOUS GIFT BASKETS
# 2  AAA000000010112677      LIESCHESKI FOUNDATION REPAIR
# 3  AAA000000010112678  BEIJING YDZL TECHNOLOGY CO., LTD
# 4  AAA000000010112679      LIESCHESKI FOUNDATION REPAIR
#
#                                                 Addr       City State  \
# 0                          115 GOLF COURSE RD STE E       LOGAN    UT
# 1                                 3200 PALM TREE DR    LITHONIA    GA
# 2                                1476 HIGHWAY 159 E   BELLVILLE    TX
# 3  ROOM 310, FLOOR 3, BUILDING 1-4, SOUTH SIDE BE...    BEIJING    CN
# 4                                1476 HIGHWAY 159 E   BELLVILLE    TX
#
#          Zip BusinessPhone TaxIdNumber HistoryDate  sufficient_input  \
# 0  843215934    4355353654                20210701                 0
# 1  300382361    7708857033                20210701                 0
# 2  774185805    9798653142                20210701                 0
# 3  000100000    1064362748                20210701                 0
# 4  774185805    9798653142                20210701                 0
#
#        HistoryDateTime
# 0  2021-07-01T00:00:00
# 1  2021-07-01T00:00:15
# 2  2021-07-01T00:00:21
# 3  2021-07-01T00:00:22
# 4  2021-07-01T00:00:23

# %%
data.to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_cleaned_filtered_input.parquet",
             format = ".parquet")

# %%
data.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',
#        'sufficient_input', 'count'],
#       dtype='object')

# %%
print(data[data['AccountNumber'].str.strip() == ""].shape)
print(data[data['CompanyName'].str.strip() == ""].shape)
print(data[data['AlternateCompanyName'].str.strip() == ""].shape)
print(data[data['Addr'].str.strip() == ""].shape)
print(data[data['City'].str.strip() == ""].shape)
print(data[data['State'].str.strip() == ""].shape)
print(data[data['Zip'].str.strip() == ""].shape)
print(data[data['BusinessPhone'].str.strip() == ""].shape)
print(data[data['TaxIdNumber'].str.strip() == ""].shape)
print(data[data['HistoryDate'].str.strip() == ""].shape)
# Out:
# (0, 12)
# (0, 12)
# (92855298, 12)
# (3, 12)
# (2552188, 12)
# (2545788, 12)
# (5359102, 12)
# (28167156, 12)
# (87548889, 12)
# (0, 12)

# %%
data["count"] = 1
dedup_bii =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ])['count'].sum().reset_index(name='count')
fmt = make_format(cuts = [-np.inf, 0, 1, 2, 3, 4, 5, 10, 100, 1000, np.inf])
freq(dedup_bii["count"], format = [fmt])
# Out:
#               Count       Pct  Cuml Count  Cuml Pct
# count
# <= 0            0.0  0.000000         0.0  0.000000
# 1         7425137.0  0.428920   7425137.0  0.428920
# 2         3061059.0  0.176825  10486196.0  0.605745
# 3          810805.0  0.046837  11297001.0  0.652582
# 4          505334.0  0.029191  11802335.0  0.681773
# 5          288999.0  0.016694  12091334.0  0.698468
# 6-10      2736862.0  0.158097  14828196.0  0.856565
# 11-100    2482181.0  0.143386  17310377.0  0.999951
# 101-1000      819.0  0.000047  17311196.0  0.999998
# 1001+          36.0  0.000002  17311232.0  1.000000
# Missing         0.0  0.000000  17311232.0  1.000000

# %%
dedup_bii["count"].describe()
# Out:
# count    1.731123e+07
# mean     5.363876e+00
# std      1.282771e+02
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      8.000000e+00
# max      5.139480e+05
# Name: count, dtype: float64

# %%
dedup_bii[dedup_bii["count"] == 513948]
# Out:
#                                 CompanyName AlternateCompanyName  \
# 6417399  GORMAN MANUFACTURING COMPANY, INC.
#
#                    Addr           City State    Zip BusinessPhone TaxIdNumber  \
# 6417399  492 KOLLER ST   SAN FRANCISCO    CA  94110    6505550000
#
#           count
# 6417399  513948

# %%
data = data.sort_values(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', "HistoryDate"])
dedup_bii = data.drop_duplicates(subset=['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ], 
                                 keep = "last", ignore_index = True)
print(dedup_bii.shape)
# Out:
# (17311232, 12)

# %%
dedup_bii[['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
       'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',]].to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_filtered_remove_dt_dedup_for_ECL.csv", 
             format = '.csv', overwrite = True, index = False)

# %% [markdown]
# ## Select 5-10Mil sample

# %%
data = pd.read_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/goodfile_futher_filtered.parquet", reader = pd.read_parquet)
print(data.shape)
# Out:
# (101152150, 11)

# %%
dedup_bii =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ])['count'].sum().reset_index(name='count')
fmt = make_format(cuts = [-np.inf, 0, 1, 2, 3, 4, 5, 10, 100, 1000, np.inf])
freq(dedup_bii["count"], format = [fmt])
# Out:
#               Count       Pct  Cuml Count  Cuml Pct
# count
# <= 0            0.0  0.000000         0.0  0.000000
# 1         7425137.0  0.428920   7425137.0  0.428920
# 2         3061059.0  0.176825  10486196.0  0.605745
# 3          810805.0  0.046837  11297001.0  0.652582
# 4          505334.0  0.029191  11802335.0  0.681773
# 5          288999.0  0.016694  12091334.0  0.698468
# 6-10      2736862.0  0.158097  14828196.0  0.856565
# 11-100    2482181.0  0.143386  17310377.0  0.999951
# 101-1000      819.0  0.000047  17311196.0  0.999998
# 1001+          36.0  0.000002  17311232.0  1.000000
# Missing         0.0  0.000000  17311232.0  1.000000

# %%
sample = dedup_bii.sample(n=1_500_000, random_state=1234, ignore_index = True)
print(sample["count"].describe())
freq(sample["count"], format = [fmt])
# Out:
# count    1.500000e+06
# mean     5.314587e+00
# std      6.979322e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      8.000000e+00
# max      1.003000e+03
# Name: count, dtype: float64
#              Count           Pct  Cuml Count  Cuml Pct
# count
# <= 0           0.0  0.000000e+00         0.0  0.000000
# 1         642817.0  4.285447e-01    642817.0  0.428545
# 2         265138.0  1.767587e-01    907955.0  0.605303
# 3          70782.0  4.718800e-02    978737.0  0.652491
# 4          43771.0  2.918067e-02   1022508.0  0.681672
# 5          25083.0  1.672200e-02   1047591.0  0.698394
# 6-10      237373.0  1.582487e-01   1284964.0  0.856643
# 11-100    214964.0  1.433093e-01   1499928.0  0.999952
# 101-1000      71.0  4.733333e-05   1499999.0  0.999999
# 1001+          1.0  6.666667e-07   1500000.0  1.000000
# Missing        0.0  0.000000e+00   1500000.0  1.000000

# %%
## merge back to full input data:
temp = data.merge(sample, on = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', ])
print(temp.shape)
# Out:
# (7971880, 13)

# %%
freq(temp.HistoryDate.str.slice(0,6))
# Out:
#                  Count       Pct  Cuml Count  Cuml Pct
# HistoryDate
# 202107        908157.0  0.113920    908157.0  0.113920
# 202108        422458.0  0.052994   1330615.0  0.166914
# 202109        648204.0  0.081311   1978819.0  0.248225
# 202110        750634.0  0.094160   2729453.0  0.342385
# 202111        606733.0  0.076109   3336186.0  0.418494
# 202112        676377.0  0.084845   4012563.0  0.503340
# 202201        935557.0  0.117357   4948120.0  0.620697
# 202202        337750.0  0.042368   5285870.0  0.663064
# 202203       1317915.0  0.165320   6603785.0  0.828385
# 202204        468558.0  0.058776   7072343.0  0.887161
# 202205        658406.0  0.082591   7730749.0  0.969752
# 202206        241131.0  0.030248   7971880.0  1.000000

# %%
temp.to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_filtered_remove_dt_for_dt_modeling.csv", 
             format = '.csv', overwrite = True, index = False)

# %%
temp = pd.read_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_filtered_remove_dt_for_dt_modeling.csv", 
             reader = pd.read_csv)
print(temp.shape)
# Out:
# (7971880, 13)

# %%
temp.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',
#        'sufficient_input', 'count_x', 'count_y'],
#       dtype='object')

# %%
temp.count_x.describe()
# Out:
# count    7971880.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0
# Name: count_x, dtype: float64

# %%
temp = temp.fillna("")

# %%
dedup_bii =temp.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', "HistoryDate"])['count_x'].sum().reset_index(name='count_x')
print(dedup_bii.shape)
fmt = make_format(cuts = [-np.inf, 0, 1, 2, 3, 4, 5, 10, 100, 1000, np.inf])
freq(dedup_bii["count_x"], format = [fmt])
# Out:
# (7213105, 10)
#               Count       Pct  Cuml Count  Cuml Pct
# count_x
# <= 0            0.0  0.000000         0.0  0.000000
# 1         6689196.0  0.927367   6689196.0  0.927367
# 2          459160.0  0.063656   7148356.0  0.991023
# 3           36265.0  0.005028   7184621.0  0.996051
# 4           10755.0  0.001491   7195376.0  0.997542
# 5            4329.0  0.000600   7199705.0  0.998142
# 6-10         7504.0  0.001040   7207209.0  0.999183
# 11-100       5852.0  0.000811   7213061.0  0.999994
# 101-1000       44.0  0.000006   7213105.0  1.000000
# 1001+           0.0  0.000000   7213105.0  1.000000
# Missing         0.0  0.000000   7213105.0  1.000000

# %%
dedup_bii['count_x'] = 1
dedup_bii2 =dedup_bii.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber'])['count_x'].sum().reset_index(name='count_x')
print(dedup_bii2.shape)
fmt = make_format(cuts = [-np.inf, 0, 1, 2, 3, 4, 5, 10, 100, 1000, np.inf])
freq(dedup_bii2["count_x"], format = [fmt])
# Out:
# (1500000, 9)
#              Count           Pct  Cuml Count  Cuml Pct
# count_x
# <= 0           0.0  0.000000e+00         0.0  0.000000
# 1         722777.0  4.818513e-01    722777.0  0.481851
# 2         252620.0  1.684133e-01    975397.0  0.650265
# 3          54926.0  3.661733e-02   1030323.0  0.686882
# 4          28978.0  1.931867e-02   1059301.0  0.706201
# 5          21594.0  1.439600e-02   1080895.0  0.720597
# 6-10      216738.0  1.444920e-01   1297633.0  0.865089
# 11-100    202366.0  1.349107e-01   1499999.0  0.999999
# 101-1000       1.0  6.666667e-07   1500000.0  1.000000
# 1001+          0.0  0.000000e+00   1500000.0  1.000000
# Missing        0.0  0.000000e+00   1500000.0  1.000000

# %%
dedup_bii2["count_x"].describe()
# Out:
# count    1.500000e+06
# mean     4.808737e+00
# std      6.341019e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      7.000000e+00
# max      1.950000e+02
# Name: count_x, dtype: float64

# %%
dedup_bii2[dedup_bii2["count_x"] == 195]
# Out:
#        CompanyName AlternateCompanyName                     Addr  \
# 556304  GOOGLE LLC                       1600 AMPHITHEATRE PKWY
#
#                  City State        Zip BusinessPhone TaxIdNumber  count_x
# 556304  MOUNTAIN VIEW    CA  940431351  6502530000.0                  195

# %% [markdown]
# ## EDA

# %%
# data.to_adls("Analytics/RnD Projects/Product RnD/Business/LexisNexis 9999 (SBFE Inquiry POC)/Data Modeling Clean/final_cleaned_filtered_input.parquet",
#              format = ".parquet")
data.columns
# Out:
# Index(['AccountNumber', 'CompanyName', 'AlternateCompanyName', 'Addr', 'City',
#        'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate',
#        'sufficient_input', 'HistoryDateTime'],
#       dtype='object')

# %%
freq(data["HistoryDate"].str.slice(0,6))
# Out:
#                   Count       Pct  Cuml Count  Cuml Pct
# HistoryDate
# 202107       10580351.0  0.113945  10580351.0  0.113945
# 202108        4961686.0  0.053435  15542037.0  0.167379
# 202109        7551680.0  0.081327  23093717.0  0.248707
# 202110        8729360.0  0.094010  31823077.0  0.342717
# 202111        7075626.0  0.076201  38898703.0  0.418917
# 202112        7874424.0  0.084803  46773127.0  0.503721
# 202201       10880052.0  0.117172  57653179.0  0.620893
# 202202        3967399.0  0.042727  61620578.0  0.663619
# 202203       15275783.0  0.164512  76896361.0  0.828131
# 202204        5498433.0  0.059215  82394794.0  0.887346
# 202205        7674972.0  0.082655  90069766.0  0.970001
# 202206        2785532.0  0.029999  92855298.0  1.000000

# %%
data["hour"] = data["HistoryDateTime"].str.slice(11, 13)
freq(data["hour"])
# Out:
#            Count       Pct  Cuml Count  Cuml Pct
# hour
# 00     7562908.0  0.081448   7562908.0  0.081448
# 01     9302182.0  0.100179  16865090.0  0.181628
# 02     5233410.0  0.056361  22098500.0  0.237989
# 03     4123220.0  0.044405  26221720.0  0.282393
# 04     1154576.0  0.012434  27376296.0  0.294828
# 05     7638569.0  0.082263  35014865.0  0.377091
# 06     6143345.0  0.066160  41158210.0  0.443251
# 07     2473964.0  0.026643  43632174.0  0.469894
# 08     5915128.0  0.063703  49547302.0  0.533597
# 09    13721959.0  0.147778  63269261.0  0.681375
# 10     4155908.0  0.044757  67425169.0  0.726132
# 11     2424135.0  0.026107  69849304.0  0.752238
# 12      795996.0  0.008572  70645300.0  0.760811
# 13      943226.0  0.010158  71588526.0  0.770969
# 14     1123767.0  0.012102  72712293.0  0.783071
# 15     2777712.0  0.029914  75490005.0  0.812985
# 16     1199524.0  0.012918  76689529.0  0.825904
# 17     1103340.0  0.011882  77792869.0  0.837786
# 18     2685047.0  0.028916  80477916.0  0.866702
# 19      827273.0  0.008909  81305189.0  0.875612
# 20     1004204.0  0.010815  82309393.0  0.886426
# 21     1092126.0  0.011762  83401519.0  0.898188
# 22      974132.0  0.010491  84375651.0  0.908679
# 23     8479647.0  0.091321  92855298.0  1.000000

# %%
data["count"] = 1

# %%
## group by timestamp
stacked_roll_1 =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDateTime',])['count'].sum().reset_index(name='count')
freq("count", df = stacked_roll_1, format = [fmt])
# Out:
#                Count           Pct  Cuml Count  Cuml Pct
# count
# <= 0             0.0  0.000000e+00         0.0  0.000000
# 1         85048628.0  9.565666e-01  85048628.0  0.956567
# 2          3811264.0  4.286639e-02  88859892.0  0.999433
# 3            35571.0  4.000774e-04  88895463.0  0.999833
# 4             9447.0  1.062532e-04  88904910.0  0.999939
# 5             2701.0  3.037893e-05  88907611.0  0.999970
# 6-10          2204.0  2.478903e-05  88909815.0  0.999994
# 11-100         486.0  5.466183e-06  88910301.0  1.000000
# 101-1000         4.0  4.498916e-08  88910305.0  1.000000
# 1001+            0.0  0.000000e+00  88910305.0  1.000000
# Missing          0.0  0.000000e+00  88910305.0  1.000000

# %%
stacked_roll_1[stacked_roll_1["count"] == 117]
# Out:
#                              CompanyName AlternateCompanyName  \
# 31892382  GIRL SCOUTS OF GREATER CHICAGO
#
#                            Addr          City State    Zip BusinessPhone  \
# 31892382  650 LAKEVIEW PARKWAY   VERNON HILLS    IL  60061       7244215
#
#          TaxIdNumber      HistoryDateTime  count
# 31892382              2022-03-01T02:25:13    117

# %%
stacked_roll_1["count"].describe()
# Out:
# count    8.891030e+07
# mean     1.044370e+00
# std      2.208217e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.170000e+02
# Name: count, dtype: float64

# %%
## group by hour
stacked_roll_1 =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate', "hour"])['count'].sum().reset_index(name='count')
print(stacked_roll_1["count"].describe())
freq("count", df = stacked_roll_1, format = [fmt])
# Out:
# count    8.403028e+07
# mean     1.105022e+00
# std      1.440820e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.114000e+03
# Name: count, dtype: float64
#                Count           Pct  Cuml Count  Cuml Pct
# count
# <= 0             0.0  0.000000e+00         0.0  0.000000
# 1         78473087.0  9.338668e-01  78473087.0  0.933867
# 2          4843583.0  5.764092e-02  83316670.0  0.991508
# 3           385850.0  4.591797e-03  83702520.0  0.996099
# 4           102552.0  1.220417e-03  83805072.0  0.997320
# 5            42372.0  5.042468e-04  83847444.0  0.997824
# 6-10         92081.0  1.095807e-03  83939525.0  0.998920
# 11-100       90444.0  1.076326e-03  84029969.0  0.999996
# 101-1000       289.0  3.439236e-06  84030258.0  1.000000
# 1001+           23.0  2.737109e-07  84030281.0  1.000000
# Missing          0.0  0.000000e+00  84030281.0  1.000000

# %%
stacked_roll_1[stacked_roll_1["CompanyName"] == "ISTCMSTEST322"]
# Out:
#             CompanyName AlternateCompanyName                Addr       City  \
# 37031244  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031245  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031246  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031247  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031248  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031249  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031250  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031251  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031252  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031253  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031254  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031255  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031256  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031257  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031258  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031259  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031260  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031261  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031262  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031263  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031264  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031265  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031266  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031267  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031268  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031269  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031270  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031271  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031272  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031273  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031274  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031275  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031276  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031277  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031278  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031279  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031280  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031281  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031282  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031283  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031284  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031285  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031286  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031287  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031288  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031289  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031290  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031291  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031292  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031293  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
# 37031294  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
#
#          State Zip BusinessPhone TaxIdNumber HistoryDate hour  count
# 37031244    CA      000000000000                20210701   10      4
# 37031245    CA      000000000000                20210716   08     95
# 37031246    CA      000000000000                20210716   09    636
# 37031247    CA      000000000000                20210716   10    658
# 37031248    CA      000000000000                20210716   11    534
# 37031249    CA      000000000000                20210716   12    559
# 37031250    CA      000000000000                20210716   13    588
# 37031251    CA      000000000000                20210716   14    580
# 37031252    CA      000000000000                20210716   15    162
# 37031253    CA      000000000000                20210722   11    293
# 37031254    CA      000000000000                20210722   12   1925
# 37031255    CA      000000000000                20210722   13   1911
# 37031256    CA      000000000000                20210722   14    700
# 37031257    CA      000000000000                20210723   03    144
# 37031258    CA      000000000000                20210723   04   1146
# 37031259    CA      000000000000                20210723   05   1929
# 37031260    CA      000000000000                20210723   06   1839
# 37031261    CA      000000000000                20210723   07   1878
# 37031262    CA      000000000000                20210723   08   1965
# 37031263    CA      000000000000                20210723   09   1967
# 37031264    CA      000000000000                20210723   10   1984
# 37031265    CA      000000000000                20210723   11   1973
# 37031266    CA      000000000000                20210723   12   2007
# 37031267    CA      000000000000                20210723   13   1943
# 37031268    CA      000000000000                20210723   14    208
# 37031269    CA      000000000000                20210726   05    897
# 37031270    CA      000000000000                20210726   06   1293
# 37031271    CA      000000000000                20210726   07   1745
# 37031272    CA      000000000000                20210726   08   1959
# 37031273    CA      000000000000                20210726   09   1937
# 37031274    CA      000000000000                20210726   10   1959
# 37031275    CA      000000000000                20210726   11   2008
# 37031276    CA      000000000000                20210726   12   1995
# 37031277    CA      000000000000                20210726   13   1978
# 37031278    CA      000000000000                20210726   14   1159
# 37031279    CA      000000000000                20210730   14      1
# 37031280    CA      000000000000                20210802   10      1
# 37031281    CA      000000000000                20210803   14      3
# 37031282    CA      000000000000                20210817   17      1
# 37031283    CA      000000000000                20210817   21      1
# 37031284    CA      000000000000                20211005   18      2
# 37031285    CA      000000000000                20211025   12      1
# 37031286    CA      000000000000                20211025   14      5
# 37031287    CA      000000000000                20211025   15      2
# 37031288    CA      000000000000                20211026   09      1
# 37031289    CA      000000000000                20211026   12      9
# 37031290    CA      000000000000                20211026   15      2
# 37031291    CA      000000000000                20211026   16      2
# 37031292    CA      000000000000                20211122   15      1
# 37031293    CA      000000000000                20211212   12      3
# 37031294    CA      000000000000                20220114   14      1

# %%
stacked_roll_1[stacked_roll_1["count"] == 2114]
# Out:
#                              CompanyName AlternateCompanyName  \
# 30271541  GIRL SCOUTS OF GREATER CHICAGO
#
#                            Addr          City State    Zip BusinessPhone  \
# 30271541  650 LAKEVIEW PARKWAY   VERNON HILLS    IL  60061       7244215
#
#          TaxIdNumber HistoryDate hour  count
# 30271541                20220301   02   2114

# %%
## group by date
stacked_roll_1 =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate'])['count'].sum().reset_index(name='count')
print(stacked_roll_1["count"].describe())
freq("count", df = stacked_roll_1, format = [fmt])
# Out:
# count    8.319994e+07
# mean     1.116050e+00
# std      4.446888e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.898300e+04
# Name: count, dtype: float64
#                Count       Pct  Cuml Count  Cuml Pct
# count
# <= 0             0.0  0.000000         0.0  0.000000
# 1         77155338.0  0.927348  77155338.0  0.927348
# 2          5292931.0  0.063617  82448269.0  0.990965
# 3           418393.0  0.005029  82866662.0  0.995994
# 4           125097.0  0.001504  82991759.0  0.997498
# 5            49797.0  0.000599  83041556.0  0.998096
# 6-10         87000.0  0.001046  83128556.0  0.999142
# 11-100       69085.0  0.000830  83197641.0  0.999972
# 101-1000      1977.0  0.000024  83199618.0  0.999996
# 1001+          323.0  0.000004  83199941.0  1.000000
# Missing          0.0  0.000000  83199941.0  1.000000

# %%
stacked_roll_1[stacked_roll_1["CompanyName"] == "GIRL SCOUTS OF GREATER CHICAGO"]
# Out:
#                              CompanyName AlternateCompanyName  \
# 29960592  GIRL SCOUTS OF GREATER CHICAGO
# 29960593  GIRL SCOUTS OF GREATER CHICAGO
# 29960594  GIRL SCOUTS OF GREATER CHICAGO
# 29960595  GIRL SCOUTS OF GREATER CHICAGO
# 29960596  GIRL SCOUTS OF GREATER CHICAGO
# 29960597  GIRL SCOUTS OF GREATER CHICAGO
# 29960598  GIRL SCOUTS OF GREATER CHICAGO
#
#                            Addr          City State        Zip BusinessPhone  \
# 29960592       1005 W 178TH ST       HOMEWOOD    IL      60430    8475730500
# 29960593     1551 SPENCER ROAD         JOLIET    IL  604338591    3129126373
# 29960594  20 S CLARK ST LBBY 2        CHICAGO    IL  606031809    3124162500
# 29960595          3155 71ST ST      WOODRIDGE    IL      60517    3124162500
# 29960596  650 LAKEVIEW PARKWAY   VERNON HILLS    IL      60061       7244215
# 29960597  650 LAKEVIEW PARKWAY   VERNON HILLS    IL      60061       7244215
# 29960598         8699 BROADWAY   MERRILLVILLE    IN  464107012    3124162500
#
#          TaxIdNumber HistoryDate  count
# 29960592                20220301     46
# 29960593                20220301    119
# 29960594                20220316      1
# 29960595                20220301     58
# 29960596                20211223      1
# 29960597                20220301   2114
# 29960598                20220301     53

# %%
stacked_roll_1[stacked_roll_1["count"] == 18983]
# Out:
#             CompanyName AlternateCompanyName                Addr       City  \
# 36642797  ISTCMSTEST322                       915    E BRETT ST   INGLEWOOD
#
#          State Zip BusinessPhone TaxIdNumber HistoryDate  count
# 36642797    CA      000000000000                20210723  18983

# %%
## group by date
stacked_roll_1 =data.groupby(by = ['CompanyName', 'AlternateCompanyName', 'Addr', 'City', 'State', 'Zip', 'BusinessPhone', 'TaxIdNumber', 'HistoryDate'])['count'].sum().reset_index(name='count')
print(stacked_roll_1["count"].describe())
freq("count", df = stacked_roll_1, format = [fmt])
